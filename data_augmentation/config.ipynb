# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
aug_dir = '/content/drive/MyDrive/CSC4046 - Individual Research/text_classification/data_augmentation'
classification_dir = '/content/drive/MyDrive/CSC4046 - Individual Research/text_classification'

# %%
# !ls
# Out:
# drive  sample_data

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# merge files - train set
INPUT_1 = 'datasets/agnews/original_data/train.txt'
INPUT_2 = 'datasets/agnews/original_data/train_labels.txt'
OUTPUT = 'datasets/agnews/augmented_data/train_merged_output.txt'

# %cd '{aug_dir}/file_op'

# !python merge.py --input_1 '{classification_dir}/{INPUT_1}' --input_2 '{classification_dir}/{INPUT_2}' --output '{classification_dir}/{OUTPUT}'
# Out:
# /content/drive/MyDrive/Level 4/CSC4046 - Individual Research/text_classification/data_augmentation/file_op
# Created file /content/drive/MyDrive/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data/train_merged_output.txt

# %%
# apply augmentation - train set
DATASET = 'datasets/agnews/augmented_data'
INPUT = 'train_merged_output.txt'
OUTPUT = 'train_augmented_output.txt'

# %cd '{aug_dir}'

# !python 'code/augment.py' --input '{classification_dir}/{DATASET}/{INPUT}' --output '{classification_dir}/{DATASET}/{OUTPUT}' --num_aug 2
# Out:
# /content/drive/MyDrive/Level 4/CSC4046 - Individual Research/text_classification/data_augmentation
# generated augmented sentences with eda for /content/drive/MyDrive/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data/train_merged_output.txt to /content/drive/MyDrive/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data/train_augmented_output.txt with num_aug=2

# %%
# break the output - train set
DATASET = 'datasets/agnews/augmented_data'
AUGMENTED_INPUT = 'train_augmented_output.txt'
OUTPUT = 'train.txt'
OUTPUT_LABEL = 'train_labels.txt'

# %cd '{aug_dir}/file_op'

# !python break.py  --augmented_input '{classification_dir}/{DATASET}/{AUGMENTED_INPUT}' --output '{classification_dir}/{DATASET}/{OUTPUT}' --label_output '{classification_dir}/{DATASET}/{OUTPUT_LABEL}'
# Out:
# /content/drive/MyDrive/Level 4/CSC4046 - Individual Research/text_classification/data_augmentation/file_op
# Splitted file /content/drive/MyDrive/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data/train_augmented_output.txt

# %%
# merge files - test set

INPUT_1 = 'datasets/agnews/original_data/test.txt'
INPUT_2 = 'datasets/agnews/original_data/test_labels.txt'
OUTPUT = 'datasets/agnews/augmented_data/test_merged_output.txt'

# %cd '{aug_dir}/file_op'

# !python merge.py --input_1 '{classification_dir}/{INPUT_1}' --input_2 '{classification_dir}/{INPUT_2}' --output '{classification_dir}/{OUTPUT}'
# Out:
# /content/drive/MyDrive/Level 4/CSC4046 - Individual Research/text_classification/data_augmentation/file_op
# Created file /content/drive/MyDrive/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data/test_merged_output.txt

# %%
# apply augmentation - test set
DATASET = 'datasets/agnews/augmented_data'
INPUT = 'test_merged_output.txt'
OUTPUT = 'test_augmented_output.txt'

# %cd '{aug_dir}'

# !python 'code/augment.py' --input '{classification_dir}/{DATASET}/{INPUT}' --output '{classification_dir}/{DATASET}/{OUTPUT}' --num_aug 2
# Out:
# /content/drive/MyDrive/Level 4/CSC4046 - Individual Research/text_classification/data_augmentation
# generated augmented sentences with eda for /content/drive/MyDrive/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data/test_merged_output.txt to /content/drive/MyDrive/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data/test_augmented_output.txt with num_aug=2

# %%
# break the output - test set
DATASET = 'datasets/agnews/augmented_data'
AUGMENTED_INPUT = 'test_augmented_output.txt'
OUTPUT = 'test.txt'
OUTPUT_LABEL = 'test_labels.txt'

# %cd '{aug_dir}/file_op'

# !python break.py  --augmented_input '{classification_dir}/{DATASET}/{AUGMENTED_INPUT}' --output '{classification_dir}/{DATASET}/{OUTPUT}' --label_output '{classification_dir}/{DATASET}/{OUTPUT_LABEL}'
# Out:
# /content/drive/MyDrive/Level 4/CSC4046 - Individual Research/text_classification/data_augmentation/file_op
# Splitted file /content/drive/MyDrive/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data/test_augmented_output.txt

# %%
# delete unnecessary files
DIR = 'datasets/agnews/augmented_data'

# %cd '{classification_dir}/{DIR}'
# !rm test_merged_output.txt train_merged_output.txt test_augmented_output.txt train_augmented_output.txt
# !ls
# Out:
# /content/drive/MyDrive/Level 4/CSC4046 - Individual Research/text_classification/datasets/agnews/augmented_data
# label_names.txt  test_labels.txt  test.txt  train_labels.txt  train.txt
